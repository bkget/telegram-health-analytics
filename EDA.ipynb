# %%
# 1. Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# 2. Load environment variables
load_dotenv()

# 3. PostgreSQL connection setup
DB_USER = os.getenv("POSTGRES_USER", "postgres")
DB_PASS = os.getenv("POSTGRES_PASSWORD", "postgres")
DB_HOST = os.getenv("POSTGRES_HOST", "db")
DB_PORT = os.getenv("POSTGRES_PORT", "5432")
DB_NAME = os.getenv("POSTGRES_DB", "telegram_data_db")

DATABASE_URL = f"postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(DATABASE_URL)

# %%
query = """
SELECT * FROM public_staging.stg_telegram_messages;
"""
df = pd.read_sql(query, engine)
df
# Out:
#         id              source_file                date  \
# 0        1     CheMed123_2025-07-17 2023-02-10 12:23:06
# 1        2     CheMed123_2025-07-17 2023-02-02 08:58:52
# 2        3     CheMed123_2025-07-17 2023-02-01 08:59:37
# 3        4     CheMed123_2025-07-17 2023-01-31 09:19:53
# 4        5     CheMed123_2025-07-17 2023-01-30 09:45:25
# ...    ...                      ...                 ...
# 3374  3375  tikvahpharma_2025-07-17 2025-07-14 17:00:32
# 3375  3376  tikvahpharma_2025-07-17 2025-07-14 16:28:24
# 3376  3377  tikvahpharma_2025-07-17 2025-07-14 15:18:57
# 3377  3378  tikvahpharma_2025-07-17 2025-07-14 14:59:12
# 3378  3379  tikvahpharma_2025-07-17 2025-07-14 14:14:25
#
#                                                    text   views       from_id  \
# 0     ⚠️Notice!\nDear esteemed customers,\nDue to fo...  1222.0           NaN
# 1     Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...  1123.0           NaN
# 2     አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...  1015.0           NaN
# 3     Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...   784.0           NaN
# 4     Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...   681.0           NaN
# ...                                                 ...     ...           ...
# 3374  PHARMAKON TRADING HOUSE PLC(IMPORTER)\n\n   ♟G...   775.0  1.353258e+09
# 3375  Tikvah Sales\n(Pharma Import)\n\n⬇️🆕arrival \n...   997.0  1.353258e+09
# 3376  NEW JOB VACCANCY \n08/11/2017\nJUNIOR PHARMACY...   716.0  1.353258e+09
# 3377  From import  \n\n🚨 New Arrival: Medical Equipm...   719.0  1.353258e+09
# 3378  የብቃት ምዘና ፈተና ለመውሰድ በመጠባበቅ ላይ ለምትገኙ ጤና ባለሙያዎች በ...   850.0  1.353258e+09
#
#       replies  forwards
# 0         NaN       1.0
# 1         NaN       3.0
# 2         NaN       4.0
# 3         NaN       1.0
# 4         NaN       2.0
# ...       ...       ...
# 3374      0.0       0.0
# 3375      0.0       1.0
# 3376      0.0       3.0
# 3377      0.0       0.0
# 3378      0.0       1.0
#
# [3379 rows x 8 columns]
